# %%
import pandas as pd
import glob
import os

# Caminho da pasta onde estão os CSVs
pasta = r'C:\Projetos Python\WebScraping_SofaScore\data\outputs\silver\2025-04-28_14-41-41\Matches'

# Pega todos os arquivos CSV da pasta
arquivos_csv = glob.glob(os.path.join(pasta, '*.csv'))

# Lê todos os CSVs e armazena numa lista de DataFrames
lista_df = [pd.read_csv(arquivo) for arquivo in arquivos_csv]

# Concatena todos os DataFrames um abaixo do outro
df = pd.concat(lista_df, ignore_index=True)

# Exibe o resultado
df
# Out:
#      season_id_round_slug  unique_tournament_id  season_id  round slug  \
# 0                  571201                 10294      57120      1  NaN
# 1                  571201                 10294      57120      1  NaN
# 2                  571201                 10294      57120      1  NaN
# 3                  571201                 10294      57120      1  NaN
# 4                  571202                 10294      57120      2  NaN
# ...                   ...                   ...        ...    ...  ...
# 2165               569749                    92      56974      9  NaN
# 2166               569749                    92      56974      9  NaN
# 2167               569749                    92      56974      9  NaN
# 2168               569749                    92      56974      9  NaN
# 2169               569749                    92      56974      9  NaN
#
#                        tournament_name  match_id  cup_round_type  \
# ...

# %%
df[df['match_id'] == 11874767]
# Out:
#     season_id_round_slug  unique_tournament_id  season_id  round slug  \
# 396               570061                 11682      57006      1  NaN
#
#           tournament_name  match_id  cup_round_type          match_slug  \
# 396  Brasiliense, Série A  11874767             NaN  planaltina-ec-gama
#
#      match_timestamp             match_datatime  home_team_id home_team_name  \
# 396       1705185000  2024-01-13 19:30:00-03:00          1978           Gama
#
#      home_score  away_score away_team_name  away_team_id
# 396         2.0         0.0  Planaltina EC        394962
